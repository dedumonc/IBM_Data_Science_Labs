# %% [markdown]
# # My Jupyter Notebook on IMB Data Science Experience

# %% [markdown]
# **Danielle Dumonceaux**
# Practice Team Lead

# %% [markdown]
# *I am interested in Data Science because I am drawn towards making sense out of the incomprehensible. I am a language learner, and Data Science is made up of many different languages. Within Data Science, I am able to be a curious thinker who can see items from various perspectives.*

# %% [markdown]
# ### In cell 5, the code is to calcuate the sum of 1 + 1

# %%
1 + 1
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20200324151109-0000
# KERNEL_ID = 99f1c2eb-9006-4a32-99ed-27acecc57f8a
# 2

# %% [markdown]
# 1. Cookies
#   * Chocolate Chip
#   * Oatmeal
#   * Peanut Butter
# 2. Cereal
#   * Captain Crunch
#   * Special K
#     * Berries
#     * Mocha Swirl
# 3. Bread
#   * Cinnamon
#   * Wheat
#   * White
#
# ---
#
# | Cookie      | Quanity    | Taste     |
# | :---        |   :----:   |   ---:    |
# | Chocolate   | 12         | Good      |
# | Oatmeal     | 24         | Better    |
# | Peanut      | 16         | Best      |
#
# ---
#
# ### To Do List
# 1. ~~Clean the bathroom~~
# 2. Grocery Shopping
# 3. Make Supper
# 4. Organize Shoes
# 5. ~~Eat all the cookies~~
#
# ---
#
# > While it may be very difficult to do, we must all tell ourselves that even thugh there are tons of cookies in the cabinet, we must not eat all the cookies in one sitting. If we eat all these cookies, then we will not have any cookies to eat at the next sitting. However, if we must eat all the cookies, be sure to save the best ones for the last.
#
# ---
#
# ![Unknown-1.jpeg](attachment:Unknown-1.jpeg)
